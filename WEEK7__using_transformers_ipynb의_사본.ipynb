# %% [markdown]
# <a href="https://colab.research.google.com/github/soohyoen/artificial-intelligence/blob/main/WEEK7__using_transformers_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## WEEK 7 using transfomers
# - author: Eu-Bin KIM
# - date: 16th of September
#
#
# transformers로는 무엇을 할 수 있나?
# 1. Question Answering
# 2. Summarizer
# 3. Text Generation
# 4. Filling Mask

# %%
# !pip3 install transformers
from transformers import pipeline
from pprint import pprint
# Out:
# ...
#      |████████████████████████████████| 2.8 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 47.8 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 34.1 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 636 kB 48.3 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %% [markdown]
# ## Quetion Answering

# %%
def main():
    # --- Extractive Question Answering --- #
    # using: https://huggingface.co/monologg/koelectra-base-v3-finetuned-korquad
    question_answerer = pipeline("question-answering",
                                 model="monologg/koelectra-base-v2-finetuned-korquad-384",
                                 tokenizer="monologg/koelectra-base-v2-finetuned-korquad-384")
    text = r"""
    🤗 한국의 수도는 서울이지만, 영국의 수도는 런던이다. 
    """
    questions = [
        "한국의 수도는?",
        "영국의 수도는?"
    ]
    for qus in questions:
        result = question_answerer(**{"question": qus, "context": text})
        print(qus, "->", result)


if __name__ == '__main__':
    main()
# Out:
# 한국의 수 -> {'score': 3.562927304301411e-05, 'start': 5, 'end': 6, 'answer': '🤗'}
# 영국의 -> {'score': 0.022342847660183907, 'start': 30, 'end': 34, 'answer': '런던이다'}

# %% [markdown]
# ## Summarizer

# %%
def main():
    summarizer = pipeline("summarization")
    ARTICLE = """ The dominant sequence transduction models are based on complex recurrent or convolutional neural networks in an encoder-decoder configuration.
     The best performing models also connect the encoder and decoder through an attention mechanism.
      We propose a new simple network architecture, the Transformer, based solely on attention mechanisms, dispensing with recurrence and convolutions entirely.
        Experiments on two machine translation tasks show these models to be superior in quality while being more parallelizable and requiring significantly less time to train.
         Our model achieves 28.4 BLEU on the WMT 2014 English-to-German translation task, improving over the existing best results, including ensembles by over 2 BLEU.
          On the WMT 2014 English-to-French translation task, our model establishes a new single-model state-of-the-art BLEU score of 41.8 after training for 3.5 days on eight GPUs, 
          a small fraction of the training costs of the best models from the literature. We show that the Transformer generalizes well to other tasks by applying it successfully to English constituency parsing both with large and limited training data.
              """
    print(summarizer(ARTICLE, max_length=140, min_length=30))

if __name__ == '__main__':
    main()
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)
# Downloading:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# [{'summary_text': ' The dominant sequence transduction models are based on complex recurrent or convolutional neural networks in an encoder-decoder configuration . The best performing models connect the encoder and decoder through an attention mechanism . We propose a new simple network architecture, the Transformer, based solely on attention mechanisms .'}]

# %% [markdown]
# ## Text Generation

# %%
def main():
    # Language Modeling -  Text Generation
    # using: 
    # https://huggingface.co/ehdwns1516/gpt3-kor-based_gpt2_review_SR1
    generator = pipeline(
        "text-generation",
        model="ehdwns1516/gpt3-kor-based_gpt2_review_SR1",
        tokenizer="ehdwns1516/gpt3-kor-based_gpt2_review_SR1"
    )
    context = "바다를 보지 못한 해적"
    result = generator(context)[0]
    print(result)


if __name__ == '__main__':
    main()
# Out:
# Downloading:   0%|          | 0.00/750 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/526M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/413 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/344k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/671k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:3 for open-end generation.
# {'generated_text': '바다를 보지 못한 해적이 되어버렸다.'}

# %% [markdown]
# ## Filling Mask

# %%
def main():
    # using: https://huggingface.co/kykim/bert-kor-base
    # pipeline: https://huggingface.co/transformers/task_summary.html#masked-language-modeling
    unmasker = pipeline("fill-mask",
                   model="kykim/bert-kor-base",
                   tokenizer="kykim/bert-kor-base")
    pprint(unmasker(f"나는 {unmasker.tokenizer.mask_token} 좋아해"))


if __name__ == '__main__':
    main()
# Out:
# Some weights of the model checkpoint at kykim/bert-kor-base were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [{'score': 0.13221363723278046,
#   'sequence': '나는 참 좋아해',
#   'token': 6553,
#   'token_str': '참'},
#  {'score': 0.06586632877588272,
#   'sequence': '나는 나를 좋아해',
#   'token': 16519,
#   'token_str': '나를'},
#  {'score': 0.0513581819832325,
#   'sequence': '나는 늘 좋아해',
#   'token': 3056,
#   'token_str': '늘'},
#  {'score': 0.04643082991242409,
# ...
